# %% [markdown]
# <a href="https://colab.research.google.com/github/AxithChoudhary/breast_cancer_detection_using_YOLOv5_YOLOv6_YOLOv7_YOLOv8/blob/main/Breast__Cancer_Detection_using_YOLOv6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os 
os.getcwd()
os.chdir("/content/gdrive/MyDrive/YOLOs_All/Breast_Cancer/")
path ="/content/gdrive/MyDrive/YOLOs_All/Breast_Cancer/YOLOv6/"

# %%
# !git clone https://github.com/meituan/YOLOv6
# Out:
# Cloning into 'YOLOv6'...
# remote: Enumerating objects: 3039, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 3039 (delta 14), reused 14 (delta 3), pack-reused 2994
# Receiving objects: 100% (3039/3039), 40.51 MiB | 13.55 MiB/s, done.
# Resolving deltas: 100% (1738/1738), done.
# Updating files: 100% (173/173), done.

# %%
# %cd YOLOv6
# %pip install -r requirements.txt

import torch
# import utils
# display = utils.notebook_init()
# Out:
# /content/gdrive/MyDrive/YOLOs_All/Breast_Cancer/YOLOv6
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 81.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 47.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 74.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 70.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.7/238.7 KB 31.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 78.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 12.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
# ...

# %% [markdown]
# ##Downloading Datasets

# %%
os.makedirs("datasets", exist_ok=True)

# %%
# !wget https://universe.roboflow.com/ds/gxkfsVSlQk?key=hwwKM7xFZW
# Out:
# --2023-03-11 15:48:07--  https://universe.roboflow.com/ds/gxkfsVSlQk?key=hwwKM7xFZW
# Resolving universe.roboflow.com (universe.roboflow.com)... 151.101.65.195, 151.101.1.195
# Connecting to universe.roboflow.com (universe.roboflow.com)|151.101.65.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-exports/6E1ooP0PfKW3aisFzd9ncFJbsw42/gIVWSdpxZD0IZkhTjb6d/1/mt-yolov6.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20230311%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230311T154807Z&X-Goog-Expires=901&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# ...

# %%
# !unzip /content/gdrive/MyDrive/YOLOs_All/Breast_Cancer/YOLOv6/gxkfsVSlQk?key=hwwKM7xFZW -d /content/gdrive/MyDrive/YOLOs_All/Breast_Cancer/YOLOv6/datasets
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/gdrive/MyDrive/YOLOs_All/Breast_Cancer/YOLOv6/datasets/images/train/mdb134rx_jpg.rf.f7b387a282d477e2251bd5dfed626a58.jpg
#  extracting: /content/gdrive/MyDrive/YOLOs_All/Breast_Cancer/YOLOv6/datasets/images/train/mdb134rx_jpg.rf.fcfd7ea62bbd73dcdce2da73bcb9df78.jpg
#  extracting: /content/gdrive/MyDrive/YOLOs_All/Breast_Cancer/YOLOv6/datasets/images/train/mdb141lx_jpg.rf.002e0629cb74a18611e6a7d36eafa041.jpg
#  extracting: /content/gdrive/MyDrive/YOLOs_All/Breast_Cancer/YOLOv6/datasets/images/train/mdb141lx_jpg.rf.008bd79ea257e26831f27f5b5814f444.jpg
#  extracting: /content/gdrive/MyDrive/YOLOs_All/Breast_Cancer/YOLOv6/datasets/images/train/mdb141lx_jpg.rf.0b24f9f9ae9879910ec21721314cfb89.jpg
#  extracting: /content/gdrive/MyDrive/YOLOs_All/Breast_Cancer/YOLOv6/datasets/images/train/mdb141lx_jpg.rf.0b4e7803ecfa12d1938b13f92bd28701.jpg
# ...

# %%
os.getcwd()
# Out:
# '/content/gdrive/MyDrive/YOLOs_All/Breast_Cancer/YOLOv6'

# %% [markdown]
# ##Plotting Images

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image


im_path=path+"datasets/images/train/"
label_path=path+"datasets/labels/train/"
img=random.choice(os.listdir(im_path))
print(img)

im = Image.open(im_path+img)

img_label=label_path+img.split(".jpg")[0]+".txt"
# print(img_label)
f =open(img_label,'r')
image_co=f.read().split()
# print(image_co)
x_center,y_center,im_width,im_height=image_co[1:]
# print(x_center,y_center)
width, height = im.size
# print(width*float(x_center), height*float(y_center))

fig, ax = plt.subplots()
# Display the image
ax.imshow(im)
# Create a Rectangle patch
rect = patches.Rectangle((width*float(x_center), height*float(y_center)), float(im_width)*width,float(im_height)*height, linewidth=1, edgecolor='r', facecolor='none')
# Add the patch to the Axes
ax.add_patch(rect)

plt.show()
# Out:
# mdb141lx_jpg.rf.b8746a59b49c6e89ee3b7cb4a6f596cd.jpg

# %%
import matplotlib.pyplot as plt
import random

im_path=path+"datasets/images/train/"
print(im_path)
plt.figure(figsize=(20,18))
plt.suptitle("Breast Cancer Images",fontsize=72)
for i in range(25):
  plt.subplot(5,5,i+1)
  img=random.choice(os.listdir(im_path))
  image = plt.imread(im_path+img)
  plt.imshow(image)
# Out:
# /content/gdrive/MyDrive/YOLOs_All/Breast_Cancer/YOLOv6/datasets/images/train/

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs

# %%
#P5 models
# !python tools/train.py --batch 32 --conf configs/yolov6n.py --data datasets/data.yaml --fuse_ab --device 0 --epochs 80 --img 128
# Out:
# Using 1 GPU for training...
# training args are: Namespace(data_path='datasets/data.yaml', conf_file='configs/yolov6n.py', img_size=128, batch_size=32, epochs=80, workers=8, device='0', eval_interval=20, eval_final_only=False, heavy_eval_range=50, check_images=False, check_labels=False, output_dir='./runs/train', name='exp', dist_url='env://', gpu_count=0, local_rank=-1, resume=False, write_trainbatch_tb=False, stop_aug_last_n_epoch=15, save_ckpt_on_last_n_epoch=-1, distill=False, distill_feat=False, quant=False, calib=False, teacher_model_path=None, temperature=20, fuse_ab=True, bs_per_gpu=32, rank=-1, world_size=1, save_dir='runs/train/exp6')
#
# Train: Final numbers of valid images: 2940/ labels: 2940.
# 23.5s for dataset initialization.
# Convert to COCO format
# 100% 160/160 [00:00<00:00, 155021.63it/s]
# Convert to COCO format finished. Resutls saved in datasets/annotations/instances_valid.json
# Val: Final numbers of valid images: 160/ labels: 160.
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/yolov5/runs/train-cls

# %%
# !pip install addict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python tools/train.py --resume
# Out:
# Resume training from the checkpoint file :./runs/train/exp4/weights/last_ckpt.pt
# Using 1 GPU for training...
# training args are: Namespace(data_path='datasets/data.yaml', conf_file='configs/yolov6s_finetune.py', img_size=128, batch_size=32, epochs=1, workers=8, device='0', eval_interval=20, eval_final_only=False, heavy_eval_range=50, check_images=False, check_labels=False, output_dir='./runs/train', name='exp', dist_url='env://', gpu_count=0, local_rank=-1, resume='./runs/train/exp4/weights/last_ckpt.pt', write_trainbatch_tb=False, stop_aug_last_n_epoch=15, save_ckpt_on_last_n_epoch=-1, distill=False, distill_feat=False, quant=False, calib=False, teacher_model_path=None, temperature=20, fuse_ab=True, bs_per_gpu=32, rank=-1, world_size=1, save_dir='runs/train/exp4')
#
# Train: Final numbers of valid images: 2940/ labels: 2940.
# 0.7s for dataset initialization.
# Convert to COCO format
# 100% 160/160 [00:00<00:00, 18973.92it/s]
# ...

# %%
os.getcwd()
# Out:
# '/content/gdrive/MyDrive/YOLOs_All/Breast_Cancer/YOLOv6'

# %%
# !python tools/eval.py --data datasets/data.yaml --img-size 128 --weights runs/train/exp6/weights/best_ckpt.pt --device 0
# Out:
# Namespace(data='datasets/data.yaml', weights='runs/train/exp6/weights/best_ckpt.pt', batch_size=32, img_size=128, conf_thres=0.03, iou_thres=0.65, task='val', device='0', half=False, save_dir='runs/val/', name='exp', test_load_size=640, letterbox_return_int=False, scale_exact=False, force_no_pad=False, not_infer_on_rect=False, reproduce_640_eval=False, eval_config_file='./configs/experiment/eval_640_repro.py', do_coco_metric=True, do_pr_metric=False, plot_curve=True, plot_confusion_matrix=False, verbose=False, config_file='')
# Loading checkpoint from runs/train/exp6/weights/best_ckpt.pt
#
# Fusing model...
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Switch model to deploy modality.
# ...

# %%
# !python tools/infer.py --weights runs/train/exp6/weights/best_ckpt.pt --source "datasets/mdb002rl_jpg.rf.c1d38c1487df3d68d700fcff126b080e.jpg"
# Out:
# Namespace(weights='runs/train/exp6/weights/best_ckpt.pt', source='datasets/mdb002rl_jpg.rf.c1d38c1487df3d68d700fcff126b080e.jpg', webcam=False, webcam_addr='0', yaml='data/coco.yaml', img_size=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device='0', save_txt=False, not_save_img=False, save_dir=None, view_img=False, classes=None, agnostic_nms=False, project='runs/inference', name='exp', hide_labels=False, hide_conf=False, half=False)
# Loading checkpoint from runs/train/exp6/weights/best_ckpt.pt
#
# Fusing model...
# Switch model to deploy modality.
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 100% 1/1 [00:00<00:00,  1.50it/s]
# Results saved to runs/inference/exp

# %%
model = torch.load("runs/train/exp6/weights/best_ckpt.pt")
print(model)
# Out:
# {'model': Model(
#   (backbone): EfficientRep(
#     (stem): RepVGGBlock(
#       (nonlinearity): ReLU(inplace=True)
#       (se): Identity()
#       (rbr_dense): Sequential(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       )
#       (rbr_1x1): Sequential(
#         (conv): Conv2d(3, 16, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       )
#     )
#     (ERBlock_2): Sequential(
#       (0): RepVGGBlock(
#         (nonlinearity): ReLU(inplace=True)
#         (se): Identity()
#         (rbr_dense): Sequential(
#           (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         )
# ...
